# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.datasets import fashion_mnist
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D
from sklearn.metrics import multilabel_confusion_matrix, plot_confusion_matrix
from keras.utils import to_categorical

sc = StandardScaler()

# %%
fashion_mnist = fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# #Arquitectura de 2 capas

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.4993 - accuracy: 0.8251
# Epoch 2/10
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.3783 - accuracy: 0.8642
# Epoch 3/10
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.3394 - accuracy: 0.8768
# Epoch 4/10
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.3131 - accuracy: 0.8848
# Epoch 5/10
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.2979 - accuracy: 0.8910
# Epoch 6/10
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.2820 - accuracy: 0.8955
# Epoch 7/10
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2704 - accuracy: 0.9002
# Epoch 8/10
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.2578 - accuracy: 0.9040
# Epoch 9/10
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.2489 - accuracy: 0.9081
# Epoch 10/10
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.2382 - accuracy: 0.9097

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
y_pred = []

for i in model.predict(test_images):
    y_pred.append(np.argmax(i))

y_pred = np.array(y_pred)
print('\nPrueba de precision:', test_acc)
# Out:
# Prueba de precision: 0.8866999745368958

# %%
cm = confusion_matrix(test_labels, y_pred)
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-99e71fdf3e1a> in <module>()
#       1
# ----> 2 cm = confusion_matrix(test_labels, y_pred)
#       3 cm
#
# NameError: name 'confusion_matrix' is not defined

# %%
plt.figure(figsize=(20,20))
sns.heatmap(cm, annot=True, fmt="d")
plt.savefig('h.png')
